# %% [markdown]
# ### 1. Define Your Objective
#
# Is it business in Leppavara area or what ?

# %% [markdown]
# ### 2. Data Collection
#
# Use Facebook Graph API for scraping data from Leppavara page. Use web scraping if necessary

# %% [markdown]
# ### 3. Data Cleaning and Preprocessing

# %% [markdown]
# ### 4. Sentiment Analysis

# %% [markdown]
# ### 5. Topic Modeling

# %% [markdown]
# ### 6. Data Visualization

# %% [markdown]
# ### 7. Business Analysis

# %% [markdown]
# ### 8. Reporting
